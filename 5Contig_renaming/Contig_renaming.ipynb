# %%
# This notebook creates a csv for supp table. 
# Idea: rename contigs, collate classification status & host calling.

# %%
import pandas as pd

# %%
genomeoverview = pd.read_csv('data/genome_by_genome_overview.csv', sep=',', index_col=0)
genomeoverview['VCstatsred'] = genomeoverview['VC Status']
genomeoverview['VCstatsred'] = genomeoverview['VCstatsred'].str.replace('Overlap.*', 'Overlap', regex=True)
nodesoverview = genomeoverview[genomeoverview['Genome'].str.contains("NODE")]
#For clustered contigs, we have 2 options. 1 = only 'NODES' in the cluster, or also refs.
#Since we already parsed those that have refs inside, we take this information into account.
clusdic = {"123_0":"Siphoviridae","49_1":"Myoviridae","75_0":"Myoviridae","207_0":"Podoviridae","252_0":"Podoviridae","213_0":"Myoviridae","188_0":"Mixed","19_0":"Siphoviridae","103_0":"Siphoviridae","119_0":"Myoviridae","6_2":"Podoviridae","20_0":"Siphoviridae","54_0":"Siphoviridae","495_0":"Myoviridae","73_0":"Siphoviridae","292_0":"Siphoviridae","39_0":"Podoviridae","531_0":"Inoviridae","95_0":"Myoviridae","544_0":"Myoviridae","112_1":"Siphoviridae","57_0":"Podoviridae","558_0":"Myoviridae","59_12":"Myoviridae","386_0":"Myoviridae","293_0":"Siphoviridae","503_0":"Mixed","496_0":"Siphoviridae","461_0":"Myoviridae","54_1":"Mixed","71_0":"Siphoviridae","471_0":"Siphoviridae","284_0":"Microviridae","454_0":"Myoviridae","665_0":"Cystoviridae"}
#Which ones are circular:
Circular = ["BP23_NODE_2_length_42653_cov_45_250447","BeeP-37-2013_NODE_2_length_40678_cov_31_109505","BeeP-35-2013_NODE_1_length_48212_cov_109_842256","BP50_NODE_4_length_51643_cov_134_843310","BeeP-43-2013_NODE_2_length_4729_cov_13_984308","BP50_NODE_1_length_71699_cov_19_894646","BP50_NODE_5_length_45555_cov_7_532597","BeeP-11-2013_NODE_61_length_13003_cov_97_347130","BP49_NODE_1_length_65331_cov_17_543582","BeeP-11-2013_NODE_8_length_46852_cov_48_771438","BeeP-11-2013_NODE_6_length_47542_cov_634_671885","BeeP-11-2013_NODE_457_length_2984_cov_21_251462","BeeP-06-2013_NODE_1_length_28373_cov_138_815486","BeeP-11-2013_NODE_2_length_102270_cov_31_231611","BP32_NODE_2_length_41333_cov_117_683684","BeeP-11-2013_NODE_1_length_180431_cov_45_996640","BeeP-38-2013_NODE_1_length_47472_cov_756_510180","BeeP-45-2013_NODE_1_length_31866_cov_26_676051","BeeP-11-2013_NODE_17_length_39362_cov_35_956828","BeeP-36-2013_NODE_1_length_32049_cov_19_863443"]

# %%
#For CRISPR host calling:
hosthit = {'Lactobacillus_kullabergensis_Lb_186': ['BP3_NODE_11_length_5694_cov_3_924816','BeeP-25-2013_NODE_16_length_8827_cov_54_463543','BeeP-17-2013_NODE_43_length_2879_cov_4_726624','BP3_NODE_20_length_3931_cov_2_478478','BeeP-35-2013_NODE_39_length_9293_cov_25_646484','BeeP-37-2013_NODE_25_length_6004_cov_14_639784','BeeP-11-2013_NODE_255_length_4427_cov_17_496322'],
           'Lactobacillus_kimbladii_Hma2': ['BP49_NODE_8_length_10567_cov_3_319070','BP1_NODE_133_length_1321_cov_0_498333','BP33_NODE_124_length_1524_cov_1_963649','BeeP-25-2013_NODE_363_length_1493_cov_12_626412','BeeP-20-2013_NODE_1_length_7781_cov_13_219107','BeeP-38-2013_NODE_1_length_47472_cov_756_510180-circular','BP1_NODE_6_length_7016_cov_3_128644','BeeP-35-2013_NODE_6_length_35076_cov_25_069488','BP1_NODE_43_length_2389_cov_3_477954','BeeP-40-2013_NODE_7_length_8325_cov_15_108632','BeeP-17-2013_NODE_43_length_2879_cov_4_726624','BeeP-37-2013_NODE_85_length_2979_cov_8_774294'],
           'Lactobacillus_apis_Hma11': ['BeeP-49-2013_NODE_12_length_13086_cov_35_861096'],'Bifidobacterium_asteroides_Bin2': ['BeeP-25-2013_NODE_23_length_6579_cov_23_502307','BeeP-45-2013_NODE_1_length_31866_cov_26_676051-circular','BP48_NODE_3_length_8991_cov_2_700000','BP19_NODE_1_length_107175_cov_15_429755','BP32_NODE_63_length_1614_cov_0_432016','BeeP-32-2013_NODE_4_length_5169_cov_6_513747','BeeP-06-2013_NODE_1_length_28373_cov_138_815486-circular','BeeP-05-2013_NODE_26_length_5231_cov_5_048312','BP48_NODE_14_length_4727_cov_3_351498'],
           'Lactobacillus_kullabergensis_Biut2': ['BeeP-38-2013_NODE_1_length_47472_cov_756_510180-circular','BeeP-37-2013_NODE_3_length_29184_cov_45_976294','BeeP-25-2013_NODE_16_length_8827_cov_54_463543','BeeP-11-2013_NODE_253_length_4434_cov_17_625430','BeeP-38-2013_NODE_2_length_19588_cov_27_430526'],
           'Lactobacillus_melliventris_Hma8': ['BeeP-37-2013_NODE_1_length_57959_cov_35_521647','BeeP-16-2013_NODE_10_length_5174_cov_6_264273','BP50_NODE_5_length_45555_cov_7_532597-circular','BP19_NODE_3_length_17422_cov_18_925264','BeeP-35-2013_NODE_39_length_9293_cov_25_646484','BeeP-35-2013_NODE_6_length_35076_cov_25_069488','BeeP-11-2013_NODE_60_length_13245_cov_11_725015','BeeP-25-2013_NODE_136_length_2488_cov_27_948569'],
           'Bifidobacterium_asteroides_Bin7': ['BP19_NODE_1_length_107175_cov_15_429755','BP33_NODE_110_length_1671_cov_0_356129','BP49_NODE_3_length_32202_cov_5_285465','BeeP-45-2013_NODE_1_length_31866_cov_26_676051-circular','BP50_NODE_6_length_32162_cov_68_937486','BP8_NODE_5_length_4173_cov_9_244571'],
           'Bifidobacterium_asteroides_Hma3': ['BP45_NODE_6_length_6188_cov_1_293226','BeeP-06-2013_NODE_1_length_28373_cov_138_815486-circular','BP50_NODE_6_length_32162_cov_68_937486','BP24_NODE_54_length_2932_cov_1_362860','BP45_NODE_10_length_4407_cov_1_507933','BP35_NODE_1_length_10513_cov_4_059950']}
contighit = {}
for i in hosthit:
    for j in hosthit[i]:
        if j.replace('-circular','') in contighit:
            contighit[j.replace('-circular','')].append(i)
        else:
            contighit[j.replace('-circular','')] = [i]
contighit
# Out:
# {'BP3_NODE_11_length_5694_cov_3_924816': ['Lactobacillus_kullabergensis_Lb_186'],
#  'BeeP-25-2013_NODE_16_length_8827_cov_54_463543': ['Lactobacillus_kullabergensis_Lb_186',
#   'Lactobacillus_kullabergensis_Biut2'],
#  'BeeP-17-2013_NODE_43_length_2879_cov_4_726624': ['Lactobacillus_kullabergensis_Lb_186',
#   'Lactobacillus_kimbladii_Hma2'],
#  'BP3_NODE_20_length_3931_cov_2_478478': ['Lactobacillus_kullabergensis_Lb_186'],
#  'BeeP-35-2013_NODE_39_length_9293_cov_25_646484': ['Lactobacillus_kullabergensis_Lb_186',
#   'Lactobacillus_melliventris_Hma8'],
#  'BeeP-37-2013_NODE_25_length_6004_cov_14_639784': ['Lactobacillus_kullabergensis_Lb_186'],
#  'BeeP-11-2013_NODE_255_length_4427_cov_17_496322': ['Lactobacillus_kullabergensis_Lb_186'],
#  'BP33_NODE_2_length_30045_cov_21_759190': ['Lactobacillus_apis_Lb_185'],
#  'BeeP-25-2013_NODE_77_length_3407_cov_18_130030': ['Lactobacillus_apis_Lb_185'],
#  'BP23_NODE_11_length_12964_cov_6_093436': ['Lactobacillus_apis_Lb_185'],
# ...

# %%
namelist = []
for i in nodesoverview['Genome']:
    genomnam = i
    clusstat = list(nodesoverview[nodesoverview['Genome'] == i]['VC Status'])[0]
    Genomelen = int(i.split('_')[4])
    if clusstat == 'Clustered':
        if list(nodesoverview[nodesoverview['Genome'] == i]['VC'])[0] in clusdic:
            clusname = clusdic[list(nodesoverview[nodesoverview['Genome'] == i]['VC'])[0]]
    else:
        clusname = 'nan'  
    VCnum = list(nodesoverview[nodesoverview['Genome'] == i]['VC'])[0]
    if i in contighit:
        bacnam = contighit[i][0].split('_')[0]
    else:
        bacnam = 'nan'
    if i in Circular:
        cirstat = 'Circular'
    else:
        cirstat = 'Linear'
    namelist.append([genomnam,Genomelen,cirstat,clusstat,VCnum,clusname,bacnam])

# %%
namelist.sort(key=lambda x: x[1],reverse=True)

# %%
namelist
# Out:
# [['BeeP-11-2013_NODE_1_length_180431_cov_45_996640',
#   180431,
#   'Circular',
#   'Clustered',
#   '59_12',
#   'Myoviridae',
#   'nan'],
#  ['BeeP-49-2013_NODE_1_length_137464_cov_264_909103',
#   137464,
#   'Linear',
#   'Overlap (VC_181/VC_348)',
#   nan,
#   'nan',
#   'nan'],
#  ['BP50_NODE_1_length_71699_cov_19_894646',
#   71699,
#   'Circular',
#   'Clustered',
#   '6_2',
#   'Podoviridae',
#   'nan'],
#  ['BP49_NODE_1_length_65331_cov_17_543582',
#   65331,
#   'Circular',
#   'Clustered',
#   '261_0',
#   'Siphoviridae',
#   'nan'],
#  ['BeeP-11-2013_NODE_3_length_61196_cov_356_638901',
#   61196,
#   'Linear',
#   'Clustered',
#   '292_0',
#   'Siphoviridae',
#   'nan'],
#  ['BeeP-48-2013_NODE_1_length_60809_cov_188_714631',
#   60809,
#   'Linear',
#   'Clustered',
#   '383_0',
#   'Myoviridae',
#   'nan'],
#  ['BP50_NODE_4_length_51643_cov_134_843310',
#   51643,
#   'Circular',
#   'Clustered',
#   '167_0',
#   'Podoviridae',
#   'nan'],
# ...
